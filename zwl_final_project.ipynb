# %% [markdown]
# <b id="top"></b>
# # Final project

# %% [markdown]
# ## A car with a full tank of gas drives 80 miles per hour for 3 hours before running out of gas. How many miles can the car go per tank?

# %%
total_miles=80
total_hours=3
Milesperhour=total_miles/total_hours
print(Milesperhour)
# Out:
# 26.666666666666668

# %% [markdown]
# ## A runner travels a half marathon (13.1 miles) in 3 hours. How fast was this runner going in miles per hour?

# %%
tmiles=13.1
ttime=3
miles_per_hour=13.1/3
print(miles_per_hour)
# Out:
# 4.366666666666666

# %% [markdown]
# ## The spread of a virus is exponential. If 5 people are infected and each person infects 2 other people, how many people have been infected after 5 rounds of infection?

# %%
initial_inf = 5
inf_rate = 2
rounds = 5

infected = initial_inf * (inf_rate ** rounds)
print(infected)
# Out:
# 160

# %% [markdown]
# 1. ### Unit 2B: Working with Jupyter Notebook
#  - [ ] Create a new notebook
#  * [x] Open existing notebooks
#  * Save, rename, download, and checkpoint a notebook
#  - Execute (run) Markdown and Code cells
#  - Switch between Markdown and Code cells
#  - Insert, move, and delete cells
# 2. ### Unit 2C: Working with Jupyter Notebook in R
#  > Generate an environment to run a Jupyter Notebook with R code

# %% [markdown]
# *italics*

# %% [markdown]
# **blod**

# %% [markdown]
# ![008i8TUMly1hb7tbm4idoj318g1uo4qp.jpg](attachment:008i8TUMly1hb7tbm4idoj318g1uo4qp.jpg)

# %% [markdown]
# [Go to top](#top)
